# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("AmesHousing.csv",usecols=['Lot Frontage','Lot Area'])
df.head()
# Out:
#    Lot Frontage  Lot Area
# 0         141.0     31770
# 1          80.0     11622
# 2          81.0     14267
# 3          93.0     11160
# 4          74.0     13830

# %%
df.isnull().sum()
# Out:
# Lot Frontage    490
# Lot Area          0
# dtype: int64

# %%
df['Lot Frontage'].fillna(df['Lot Frontage'].mean(),inplace=True)
df.head()
# Out:
#    Lot Frontage  Lot Area
# 0         141.0     31770
# 1          80.0     11622
# 2          81.0     14267
# 3          93.0     11160
# 4          74.0     13830

# %%
df.isnull().sum()
# Out:
# Lot Frontage    0
# Lot Area        0
# dtype: int64

# %%
df['Average']=1+df['Lot Area']
df.head()
# Out:
#    Lot Frontage  Lot Area  Average
# 0         141.0     31770    31771
# 1          80.0     11622    11623
# 2          81.0     14267    14268
# 3          93.0     11160    11161
# 4          74.0     13830    13831

# %%
df['Probbability']=df['Lot Frontage']/df['Lot Area']
df.head()
# Out:
#    Lot Frontage  Lot Area  Average  Probbability
# 0         141.0     31770    31771      0.004438
# 1          80.0     11622    11623      0.006883
# 2          81.0     14267    14268      0.005677
# 3          93.0     11160    11161      0.008333
# 4          74.0     13830    13831      0.005351

# %%
df['Lot Area'].unique()
# Out:
# array([31770, 11622, 14267, ...,  7937,  8885, 10441], dtype=int64)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
newdf=scaler.fit(df)
newdf
# Out:
# StandardScaler()

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
newdf1=scaler.fit_transform(df)
newdf1
# Out:
# array([[ 2.48859217,  2.74438073,  2.74438073, -0.58771822],
#        [ 0.66735543,  0.18709726,  0.18709726,  0.07706674],
#        [ 0.69721177,  0.5228137 ,  0.5228137 , -0.25080899],
#        ...,
#        [ 0.12994131,  0.03719892,  0.03719892, -0.17993828],
#        [ 0.57778641, -0.01750572, -0.01750572,  0.29694767],
#        [ 0.48821739, -0.06611797, -0.06611797,  0.29542711]])

# %%
from sklearn.preprocessing import RobustScaler
rscaler=RobustScaler()
newdfr=rscaler.fit_transform(df)
newdfr
# Out:
# array([[ 2.22857143,  5.427339  ,  5.427339  , -1.03623054],
#        [ 0.48571429,  0.53110571,  0.53110571, -0.19867604],
#        [ 0.51428571,  1.17387606,  1.17387606, -0.61176269],
#        ...,
#        [-0.02857143,  0.24410693,  0.24410693, -0.52247355],
#        [ 0.4       ,  0.13936817,  0.13936817,  0.07834927],
#        [ 0.31428571,  0.04629405,  0.04629405,  0.07643354]])

# %%
plt.hist(newdf1[:1],bins=4)
# Out:
# (array([[0., 0., 0., 1.],
#         [0., 0., 0., 1.],
#         [0., 0., 0., 1.],
#         [1., 0., 0., 0.]]),
#  array([-0.58771822,  0.24530652,  1.07833125,  1.91135599,  2.74438073]),
#  <a list of 4 BarContainer objects>)

# %%
plt.hist(df['Lot Area'],bins=4)
# Out:
# (array([2.922e+03, 4.000e+00, 2.000e+00, 2.000e+00]),
#  array([  1300.  ,  54786.25, 108272.5 , 161758.75, 215245.  ]),
#  <BarContainer object of 4 artists>)
